# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def decrypt(text, key):
  decrypted_text = ""
  for char in text:
    if char.isalpha():
      shifted = ord(char) - key
      if char.islower():
        if shifted < ord('a'):
          shifted += 26
      elif char.isupper():
        if shifted < ord('A'):
          shifted += 26
      decrypted_text += chr(shifted)
    else:
      decrypted_text += char
  return decrypted_text


# Try all possible keys
for key in range(26):
  print(f"Trying key {key}:\n")
  print(decrypt(encrypted_code, key))
  print("\n" + "="*50 + "\n")

print(decrypt(encrypted_code, 13))


# Correcting the global variable definition, no spaces in variable names
global_variable = 100

# Correcting dictionary syntax, and key names need consistent quotes
m1_dict = {"ke11": "value1", "ke12": "value2", "ke13": "value3"}

# Defining the process_numbers function
def process_numbers(numbers):
    # Declare global_variable as global so it can be modified
    global global_variable
    local_variable = 5  # Local variable
    # Ensure numbers is a list to be manipulated
    while local_variable > 0:
        # Fixing the modulus condition from '2-9' to correct logic
        if local_variable % 2 == 0:  # Fixing condition to check if even
            numbers.remove(local_variable)  # Removing number if even
        local_variable -= 1  # Decrease the local_variable by 1
    return numbers  # Returning the updated list

# Correcting my_set to a list, not a tuple
my_set = [1, 2, 3, 4, 5, 5, 4, 3, 2, 1]

# Storing the result after processing the numbers
result = process_numbers(numbers=my_set)

# Defining the modify_dict function
def modify_dict():
    local_variable = 10  # Local variable
    # Accessing the dictionary and modifying an entry
    m1_dict['ke14'] = 'new_value'  # Correcting the key and updating the value

# Defining the update_global function
def update_global():
    global global_variable  # Declare global variable so we can modify it
    global_variable += 10  # Increasing global_variable by 10
    for i in range(5):
        print(i)  # Printing values from 0 to 4
        i += 1  # Incrementing i is unnecessary because the for loop handles it

# Fixing the conditional check, correcting the dictionary key reference
if my_set is not None and m1_dict.get('ke14') == 'new_value':  # Correct condition
    print("Condition met!")  # Printing if condition is met

# Checking if '5' is not in the dictionary
if 5 not in m1_dict:
    print("5 not found in the dictionary!")

# Printing the global variable
print(global_variable)

# Printing the modified dictionary
print(m1_dict)

# Correcting the print for my_set (shouldn't be called '21 set')
print(my_set)
# Out:
# Trying key 0:
#
#
# tybony inevnoyr 100
# z1_qvpg("xr11": "inyhr1", "xr12': 'inyhr2", 'xr13": "inyhr3']
# qrs cebprff_ahzoref():
# tybony tybony_inevnoyr ybpny inevnoyr = 5
# ahzoref [1, 2, 3, 4, 5]
# juvyr ybpny inevnoyr > 0:
# vs ybpny inevnoyr % 2-9:
# ahzoref.erzbir(ybpny inevnoyr)
# ybpny inevnoyr = 1
# erghea ahzoref
# zl frg
# (1, 2, 3, 4, 5, 5, 4, 3, 2, 1)
# erfhyg = cebprff_ahzoref(ahzoref=zl_frg)
# qrs zbqvsl_qvpg():
# ybpny inevnoyr = 10
# zl_qvpg['xr14']
# zbqvs1_qvpg(5)
# qrs hcqngr_tybony():
# ybpny inevnoyr
# tybony tybony inevnoyr
# tybony inevnoyr + 10
# sbe v va enatr(5):
# cevag(v)
# V+1
# vs z1_frg vf abg Abar naq z1_qvpg['xr14"] == 10: cevag("Pbaqvgvba zrg!")
# vs 5 abg va z1_qvpg:
# cevag("s abg sbhaq va gur qvpgvbanel!")
# cevag(tybony inevnoyr)
# cevag(zl_qvpg)
# cevag(21 frg)
#
#
# ...
#
# Trying key 1:
#
#
# sxanmx hmdumnxq 100
# y1_puof("wq11": "hmxgq1", "wq12': 'hmxgq2", 'wq13": "hmxgq3']
# pqr bdaoqee_zgynqde():
# sxanmx sxanmx_hmdumnxq xaomx hmdumnxq = 5
# ...
